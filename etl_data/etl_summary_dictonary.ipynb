# %% [markdown]
# # Import Libraries

# %%
#Dependencies
import pandas as pd
import numpy as np
import json
import os
import requests 
import pymongo

# %% [markdown]
# # Perform API CALL

# %%
#Base URL for grabbing data from City Of Chicago
base_url ="https://data.cityofchicago.org/resource/ijzp-q8t2.geojson"

#Specify the Test URL with limit and offset parameters
#test_url ="https://data.cityofchicago.org/resource/ijzp-q8t2.geojson?$limit=50000&$offset=0&$order=id&$where=year>2017"

# %% [markdown]
# ### Define query paramerters to pull data from API

# %%
#Set parameter for API Call
offset= 0
limit = 50000 #50000
year =2020
record_counter =0

# Set empty lists to hold the combined data
crime_data = []

# %% [markdown]
# ### Paging through the data using query parameters

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")
#Paging through the data using query parameters - Loop through from pages
print(f"Loading first {limit} records.")
for i in range(5):
     query_url =f"{base_url}?$limit={limit}&$offset={offset}&$order=id&year={year}"
     #query_url =f"{base_url}?$limit={limit}&$offset={offset}&$order=id&$where=year=2018"
     #query_url =f"{base_url}?$limit={limit}&$offset={offset}&$order=id&$where=(year>2017&&year<2020)"
     print(f"Loading next {limit} records.")
     response = requests.get(query_url)
     data = response.json()
     #page = requests.get(f"https://data.cityofchicago.org/resource/ijzp-q8t2.geojson?$limit={limit}&$offset={offset}&$order=id&$where=year > 2017")
     offset += limit
     #crime_data += data
     crime_data = crime_data + data['features']
     #crime_data = crime_data + data["type"]
print("-----------------------------")
print(f"Data Retrieval Complete for {year}.Received {len(crime_data)} responses.")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Loading first 50000 records.
# Loading next 50000 records.
# Loading next 50000 records.
# Loading next 50000 records.
# Loading next 50000 records.
# Loading next 50000 records.
# -----------------------------
# Data Retrieval Complete for 2020.Received 211367 responses.

# %% [markdown]
# ### Data Validation & Preprocessing - JSON File

# %%
# Check the total number of json objects recieved
print(f"We received {len(crime_data)} responses.")
# Out:
# We received 211367 responses.

# %%
# View first json object
crime_data[0]
#print(f"The first response is {json.dumps(crime_data[0], indent=2)}.")
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-87.561272312, 41.764728045]},
#  'properties': {'location_state': '',
#   'location_zip': '',
#   'x_coordinate': '1194878',
#   'domestic': False,
#   'latitude': '41.764728045',
#   'updated_on': '2020-06-20T15:48:45.000',
#   'description': 'FIRST DEGREE MURDER',
#   'location_address': '',
#   'arrest': True,
#   'location_city': '',
#   'year': '2020',
#   'longitude': '-87.561272312',
#   'block': '072XX S SOUTH SHORE DR',
#   'fbi_code': '01A',
#   'ward': '7',
#   'id': '24889',
#   'date': '2020-01-02T02:54:00.000',
#   'beat': '0334',
#   'y_coordinate': '1857803',
#   'community_area': '43',
#   'location_description': 'APARTMENT',
#   'district': '003',
#   'iucr': '0110',
#   'case_number': 'JD101272',
#   'primary_type': 'HOMICIDE'}}

# %% [markdown]
# #### Data Exploration using pandas to create summary table

# %%
#Normalizing the json objects to pandas - Validation Columns
crime_data_pd = pd.json_normalize(crime_data)
#crime_data_pd.dtypes

# %%
#Transforming trending date to datetime format
crime_data_pd['date'] = pd.to_datetime(crime_data_pd['properties.date'], format = '%Y-%m-%dT%H:%M:%S.%f')
#crime_data_pd.dtypes

# %%
#Checking for null values
print(crime_data_pd.isnull().sum())
# Out:
# type                                    0
# geometry.type                        2900
# geometry.coordinates                 2900
# properties.location_state            2900
# properties.location_zip              2900
# properties.x_coordinate              2900
# properties.domestic                     0
# properties.latitude                  2900
# properties.updated_on                   0
# properties.description                  0
# properties.location_address          2900
# properties.arrest                       0
# properties.location_city             2900
# properties.year                         0
# properties.longitude                 2900
# properties.block                        0
# properties.fbi_code                     0
# properties.ward                         9
# properties.id                           0
# properties.date                         0
# properties.beat                         0
# properties.y_coordinate              2900
# properties.community_area               1
# properties.location_description      1216
# properties.district                     0
# properties.iucr                         0
# properties.case_number                  0
# properties.primary_type                 0
# geometry                           211363
# date                                    0
# dtype: int64

# %%
crime_data_pd['crime_month'] =crime_data_pd['date'].dt.month
crime_data_pd['crime_month_name'] =crime_data_pd['date'].dt.month_name(locale='English')

# %%
#Creating a Data Frame with Selected Columns
crime_data_df = crime_data_pd[['properties.id','properties.year','crime_month','crime_month_name','properties.description','properties.location_description',
                               'properties.primary_type','properties.arrest','properties.domestic']]

# %%
crime_data_df = crime_data_df.rename(columns=
                                      { "properties.id":"id", "properties.year":"year", "properties.arrest":"arrest",
                                        "properties.primary_type":"primary_type", "properties.domestic":"domestic",
                                        "properties.description":"description", "properties.location_description":"location_description"})

# %%
crime_data_df.head()
# Out:
#       id  year  crime_month crime_month_name          description  \
# 0  24889  2020            1          January  FIRST DEGREE MURDER
# 1  24890  2020            1          January  FIRST DEGREE MURDER
# 2  24891  2020            1          January  FIRST DEGREE MURDER
# 3  24892  2020            1          January  FIRST DEGREE MURDER
# 4  24893  2020            1          January  FIRST DEGREE MURDER
#
#   location_description primary_type  arrest  domestic
# 0            APARTMENT     HOMICIDE    True     False
# 1            APARTMENT     HOMICIDE    True     False
# 2               STREET     HOMICIDE    True     False
# 3               STREET     HOMICIDE   False     False
# 4         RETAIL STORE     HOMICIDE    True     False

# %%
crime_count= crime_data_df.groupby(['year','crime_month_name','primary_type','description'])['id'].count()
#crime_count= crime_data_df.groupby(['crime_month_name','primary_type'])['id'].count()
crime_type_summary = pd.DataFrame({'reported_crime':crime_count})
crime_type_summary =crime_type_summary.reset_index()

# %%
crime_type_dict =crime_type_summary.to_dict('records')
#crime_type_dict
f = open("../static/dump_summary_dict.json", "w")
json.dump(crime_type_dict, f)
f.close()

# %% [markdown]
# ### Loading Crime Type Dictonary in Mongo Shared

# %%
#conn = 'mongodb+srv://chicago_crime_user:chicago_crime_password@cluster0.opshg.mongodb.net/CHICAGO_CRIME_GROUPPROJECT?retryWrites=true&w=majority'
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the database in Mongo
db = client.chicago_crime

# %%
collection = db.crime_type_summary

# %%
collection.insert_many(crime_type_dict)

# %% [markdown]
# ## Jay time

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the database in Mongo
db = client.chicago_crime.crime_type_summary

type(list(db.find()))
# Out:
# list

# %%
# [
#     {'_id': ObjectId('617b40775dd8891e00990d3e'),
#         'crime_month_name': 'April',
#   'primary_type': 'ARSON',
#   'reported_crime': 35},
#     {'_id': ObjectId('617b40775dd8891e00990d3e'),
#         'crime_month_name': 'April',
#   'primary_type': 'ARSON',
#   'reported_crime': 35}
# ]

# %%
data = db.find() # for scripting is okay
data = list(db.find()) # for jupyter testing purposes

# new_data = []
# for dictionary in data:
#     placeholder_dict = {}
#     for k,v in dictionary.items():
#         if k != '_id':
#             placeholder_dict[k] = v
#     new_data.append(placeholder_list)

# print(new_data)

placeholder_dict = {}
for k,v in dictionary.items():
    if k != '_id':
        placeholder_dict[k] = v
placeholder_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-2a3994d34c38> in <module>
#      13
#      14 placeholder_dict = {}
# ---> 15 for k,v in dictionary.items():
#      16     if k != '_id':
#      17         placeholder_dict[k] = v
#
# NameError: name 'dictionary' is not defined

# %%
new_data = []

for dictionary in data:
    new_d = {k:v for k,v in dictionary.items() if k != '_id'}
    new_data.append(new_d)

new_data = [{k:v for k,v in dictionary.items() if k != '_id'} for dictionary in data]
print(new_data)
# Out:
# [{'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ARSON', 'description': 'AGGRAVATED', 'reported_crime': 5}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ARSON', 'description': 'ATTEMPT ARSON', 'reported_crime': 6}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ARSON', 'description': 'BY EXPLOSIVE', 'reported_crime': 1}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ARSON', 'description': 'BY FIRE', 'reported_crime': 23}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ASSAULT', 'description': 'AGGRAVATED - HANDGUN', 'reported_crime': 225}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ASSAULT', 'description': 'AGGRAVATED - KNIFE / CUTTING INSTRUMENT', 'reported_crime': 112}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ASSAULT', 'description': 'AGGRAVATED - OTHER DANGEROUS WEAPON', 'reported_crime': 52}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ASSAULT', 'description': 'AGGRAVATED - OTHER FIREARM', 'reported_crime': 6}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ASSAULT', 'description': 'AGGRAVATED POLICE OFFICER - HANDGUN', 'reported_crime': 3}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ASSAULT', 'description': 'AGGRAVATED POLICE OFFICER - HANDS, FISTS, FEET, NO INJURY', 'reported_crime': 5}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ASSAULT', 'description': 'AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT', 'reported_crime': 1}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ASSAULT', 'description': 'AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON', 'reported_crime': 1}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ASSAULT', 'description': 'AGGRAVATED PROTECTED EMPLOYEE - HANDGUN', 'reported_crime': 1}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ASSAULT', 'description': 'AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT', 'reported_crime': 2}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ASSAULT', 'description': 'AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON', 'reported_crime': 2}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ASSAULT', 'description': 'PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY', 'reported_crime': 14}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'ASSAULT', 'description': 'SIMPLE', 'reported_crime': 688}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'BATTERY', 'description': 'AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY', 'reported_crime': 34}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'BATTERY', 'description': 'AGG. PROTECTED EMPLOYEE - HANDS, FISTS, FEET, SERIOUS INJURY', 'reported_crime': 2}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'BATTERY', 'description': 'AGGRAVATED - HANDGUN', 'reported_crime': 139}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'BATTERY', 'description': 'AGGRAVATED - HANDS, FISTS, FEET, NO / MINOR INJURY', 'reported_crime': 6}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'BATTERY', 'description': 'AGGRAVATED - HANDS, FISTS, FEET, SERIOUS INJURY', 'reported_crime': 8}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'BATTERY', 'description': 'AGGRAVATED - KNIFE / CUTTING INSTRUMENT', 'reported_crime': 62}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'BATTERY', 'description': 'AGGRAVATED - OTHER DANGEROUS WEAPON', 'reported_crime': 101}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'BATTERY', 'description': 'AGGRAVATED DOMESTIC BATTERY - HANDGUN', 'reported_crime': 2}, {'year': '2020', 'crime_month_name': 'April', 'primary_type': 'BATTERY', 'description': 'AGGRAVATED DOMESTIC BATTERY - KNIFE / CUTTING INSTRUMENT', 'reported_crime': 52}, {'year': '2020', 'crime_month_name': 'April', 'prima ...

# %%
list(db.find())
# Out:
# [{'_id': ObjectId('617e02e00a74a2142647a588'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ARSON',
#   'description': 'AGGRAVATED',
#   'reported_crime': 5},
#  {'_id': ObjectId('617e02e00a74a2142647a589'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ARSON',
#   'description': 'ATTEMPT ARSON',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a58a'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ARSON',
#   'description': 'BY EXPLOSIVE',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a58b'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ARSON',
#   'description': 'BY FIRE',
#   'reported_crime': 23},
#  {'_id': ObjectId('617e02e00a74a2142647a58c'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED - HANDGUN',
#   'reported_crime': 225},
#  {'_id': ObjectId('617e02e00a74a2142647a58d'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 112},
#  {'_id': ObjectId('617e02e00a74a2142647a58e'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED - OTHER DANGEROUS WEAPON',
#   'reported_crime': 52},
#  {'_id': ObjectId('617e02e00a74a2142647a58f'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED - OTHER FIREARM',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a590'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED POLICE OFFICER - HANDGUN',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a591'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED POLICE OFFICER - HANDS, FISTS, FEET, NO INJURY',
#   'reported_crime': 5},
#  {'_id': ObjectId('617e02e00a74a2142647a592'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a593'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a594'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED PROTECTED EMPLOYEE - HANDGUN',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a595'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a596'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a597'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ASSAULT',
#   'description': 'PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY',
#   'reported_crime': 14},
#  {'_id': ObjectId('617e02e00a74a2142647a598'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ASSAULT',
#   'description': 'SIMPLE',
#   'reported_crime': 688},
#  {'_id': ObjectId('617e02e00a74a2142647a599'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY',
#   'reported_crime': 34},
#  {'_id': ObjectId('617e02e00a74a2142647a59a'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGG. PROTECTED EMPLOYEE - HANDS, FISTS, FEET, SERIOUS INJURY',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a59b'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED - HANDGUN',
#   'reported_crime': 139},
#  {'_id': ObjectId('617e02e00a74a2142647a59c'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED - HANDS, FISTS, FEET, NO / MINOR INJURY',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a59d'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED - HANDS, FISTS, FEET, SERIOUS INJURY',
#   'reported_crime': 8},
#  {'_id': ObjectId('617e02e00a74a2142647a59e'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 62},
#  {'_id': ObjectId('617e02e00a74a2142647a59f'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED - OTHER DANGEROUS WEAPON',
#   'reported_crime': 101},
#  {'_id': ObjectId('617e02e00a74a2142647a5a0'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED DOMESTIC BATTERY - HANDGUN',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a5a1'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED DOMESTIC BATTERY - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 52},
#  {'_id': ObjectId('617e02e00a74a2142647a5a2'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS WEAPON',
#   'reported_crime': 67},
#  {'_id': ObjectId('617e02e00a74a2142647a5a3'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED OF A CHILD',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a5a4'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED OF A SENIOR CITIZEN',
#   'reported_crime': 18},
#  {'_id': ObjectId('617e02e00a74a2142647a5a5'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MINOR INJURY',
#   'reported_crime': 34},
#  {'_id': ObjectId('617e02e00a74a2142647a5a6'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5a7'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON',
#   'reported_crime': 7},
#  {'_id': ObjectId('617e02e00a74a2142647a5a8'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a5a9'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a5aa'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'DOMESTIC BATTERY SIMPLE',
#   'reported_crime': 1442},
#  {'_id': ObjectId('617e02e00a74a2142647a5ab'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY',
#   'reported_crime': 24},
#  {'_id': ObjectId('617e02e00a74a2142647a5ac'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'description': 'SIMPLE',
#   'reported_crime': 684},
#  {'_id': ObjectId('617e02e00a74a2142647a5ad'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BURGLARY',
#   'description': 'ATTEMPT FORCIBLE ENTRY',
#   'reported_crime': 21},
#  {'_id': ObjectId('617e02e00a74a2142647a5ae'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BURGLARY',
#   'description': 'FORCIBLE ENTRY',
#   'reported_crime': 320},
#  {'_id': ObjectId('617e02e00a74a2142647a5af'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BURGLARY',
#   'description': 'HOME INVASION',
#   'reported_crime': 24},
#  {'_id': ObjectId('617e02e00a74a2142647a5b0'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'BURGLARY',
#   'description': 'UNLAWFUL ENTRY',
#   'reported_crime': 162},
#  {'_id': ObjectId('617e02e00a74a2142647a5b1'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'description': 'ARMED WHILE UNDER THE INFLUENCE',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a5b2'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'description': 'OTHER',
#   'reported_crime': 5},
#  {'_id': ObjectId('617e02e00a74a2142647a5b3'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'description': 'CRIMINAL DEFACEMENT',
#   'reported_crime': 58},
#  {'_id': ObjectId('617e02e00a74a2142647a5b4'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'description': 'INSTITUTIONAL VANDALISM',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5b5'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'description': 'TO CITY OF CHICAGO PROPERTY',
#   'reported_crime': 36},
#  {'_id': ObjectId('617e02e00a74a2142647a5b6'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'description': 'TO FIRE FIGHT.APP.EQUIP',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5b7'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'description': 'TO PROPERTY',
#   'reported_crime': 920},
#  {'_id': ObjectId('617e02e00a74a2142647a5b8'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'description': 'TO STATE SUPPORTED PROPERTY',
#   'reported_crime': 5},
#  {'_id': ObjectId('617e02e00a74a2142647a5b9'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'description': 'TO VEHICLE',
#   'reported_crime': 761},
#  {'_id': ObjectId('617e02e00a74a2142647a5ba'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'description': 'AGGRAVATED - HANDGUN',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a5bb'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'description': 'AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a5bc'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'description': 'AGGRAVATED - OTHER',
#   'reported_crime': 8},
#  {'_id': ObjectId('617e02e00a74a2142647a5bd'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'description': 'ATTEMPT AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5be'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'description': 'ATTEMPT NON-AGGRAVATED',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a5bf'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'description': 'NON-AGGRAVATED',
#   'reported_crime': 41},
#  {'_id': ObjectId('617e02e00a74a2142647a5c0'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'description': 'PREDATORY',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a5c1'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'description': 'TO LAND',
#   'reported_crime': 107},
#  {'_id': ObjectId('617e02e00a74a2142647a5c2'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'description': 'TO RESIDENCE',
#   'reported_crime': 65},
#  {'_id': ObjectId('617e02e00a74a2142647a5c3'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'description': 'TO STATE SUP LAND',
#   'reported_crime': 12},
#  {'_id': ObjectId('617e02e00a74a2142647a5c4'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'description': 'TO VEHICLE',
#   'reported_crime': 51},
#  {'_id': ObjectId('617e02e00a74a2142647a5c5'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'AGGRAVATED FINANCIAL IDENTITY THEFT',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a5c6'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'ATTEMPT - FINANCIAL IDENTITY THEFT',
#   'reported_crime': 56},
#  {'_id': ObjectId('617e02e00a74a2142647a5c7'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'BOGUS CHECK',
#   'reported_crime': 20},
#  {'_id': ObjectId('617e02e00a74a2142647a5c8'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'COMPUTER FRAUD',
#   'reported_crime': 17},
#  {'_id': ObjectId('617e02e00a74a2142647a5c9'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'COUNTERFEIT CHECK',
#   'reported_crime': 31},
#  {'_id': ObjectId('617e02e00a74a2142647a5ca'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'COUNTERFEITING DOCUMENT',
#   'reported_crime': 23},
#  {'_id': ObjectId('617e02e00a74a2142647a5cb'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'CREDIT CARD FRAUD',
#   'reported_crime': 143},
#  {'_id': ObjectId('617e02e00a74a2142647a5cc'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'DECEPTIVE COLLECTION PRACTICES',
#   'reported_crime': 8},
#  {'_id': ObjectId('617e02e00a74a2142647a5cd'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'EMBEZZLEMENT',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5ce'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'FINANCIAL EXPLOITATION OF AN ELDERLY OR DISABLED PERSON',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a5cf'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'FINANCIAL IDENTITY THEFT $300 AND UNDER',
#   'reported_crime': 129},
#  {'_id': ObjectId('617e02e00a74a2142647a5d0'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'FINANCIAL IDENTITY THEFT OVER $ 300',
#   'reported_crime': 343},
#  {'_id': ObjectId('617e02e00a74a2142647a5d1'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'FORGERY',
#   'reported_crime': 56},
#  {'_id': ObjectId('617e02e00a74a2142647a5d2'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'FRAUD OR CONFIDENCE GAME',
#   'reported_crime': 156},
#  {'_id': ObjectId('617e02e00a74a2142647a5d3'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'ILLEGAL POSSESSION CASH CARD',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a5d4'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'ILLEGAL USE CASH CARD',
#   'reported_crime': 56},
#  {'_id': ObjectId('617e02e00a74a2142647a5d5'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'INSURANCE FRAUD',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a5d6'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'STOLEN PROPERTY BUY / RECEIVE / POSSESS',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5d7'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'THEFT BY LESSEE, MOTOR VEHICLE',
#   'reported_crime': 20},
#  {'_id': ObjectId('617e02e00a74a2142647a5d8'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'THEFT BY LESSEE, NON-MOTOR VEHICLE',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5d9'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'THEFT OF LABOR / SERVICES',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a5da'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'THEFT OF LOST / MISLAID PROPERTY',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a5db'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'UNAUTHORIZED VIDEOTAPING',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5dc'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'description': 'UNLAWFUL USE OF A COMPUTER',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a5dd'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'HOMICIDE',
#   'description': 'FIRST DEGREE MURDER',
#   'reported_crime': 62},
#  {'_id': ObjectId('617e02e00a74a2142647a5de'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'description': 'OBSTRUCTING IDENTIFICATION',
#   'reported_crime': 4},
#  {'_id': ObjectId('617e02e00a74a2142647a5df'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'description': 'RESIST / OBSTRUCT / DISARM OFFICER',
#   'reported_crime': 13},
#  {'_id': ObjectId('617e02e00a74a2142647a5e0'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'INTIMIDATION',
#   'description': 'EXTORTION',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a5e1'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'INTIMIDATION',
#   'description': 'INTIMIDATION',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5e2'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'KIDNAPPING',
#   'description': 'KIDNAPPING',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5e3'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'KIDNAPPING',
#   'description': 'UNLAWFUL RESTRAINT',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5e4'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'KIDNAPPING',
#   'description': 'UNLAWFUL VISITATION INTERFERENCE',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5e5'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'description': 'LIQUOR LICENSE VIOLATION',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5e6'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'description': 'ATTEMPT - AUTOMOBILE',
#   'reported_crime': 12},
#  {'_id': ObjectId('617e02e00a74a2142647a5e7'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'description': 'ATTEMPT - TRUCK, BUS, MOTOR HOME',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5e8'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'description': 'AUTOMOBILE',
#   'reported_crime': 576},
#  {'_id': ObjectId('617e02e00a74a2142647a5e9'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'description': 'CYCLE, SCOOTER, BIKE WITH VIN',
#   'reported_crime': 20},
#  {'_id': ObjectId('617e02e00a74a2142647a5ea'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'description': 'THEFT / RECOVERY - AUTOMOBILE',
#   'reported_crime': 37},
#  {'_id': ObjectId('617e02e00a74a2142647a5eb'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'description': 'THEFT / RECOVERY - CYCLE, SCOOTER, BIKE WITH VIN',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5ec'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'description': 'THEFT / RECOVERY - TRUCK, BUS, MOBILE HOME',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5ed'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'description': 'TRUCK, BUS, MOTOR HOME',
#   'reported_crime': 11},
#  {'_id': ObjectId('617e02e00a74a2142647a5ee'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'CANNABIS PLANT',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5ef'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'FORFEIT PROPERTY',
#   'reported_crime': 4},
#  {'_id': ObjectId('617e02e00a74a2142647a5f0'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'FOUND SUSPECT NARCOTICS',
#   'reported_crime': 39},
#  {'_id': ObjectId('617e02e00a74a2142647a5f1'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'MANUFACTURE / DELIVER -  HEROIN (WHITE)',
#   'reported_crime': 14},
#  {'_id': ObjectId('617e02e00a74a2142647a5f2'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'MANUFACTURE / DELIVER - CANNABIS 10 GRAMS OR LESS',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5f3'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAMS',
#   'reported_crime': 14},
#  {'_id': ObjectId('617e02e00a74a2142647a5f4'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'MANUFACTURE / DELIVER - COCAINE',
#   'reported_crime': 4},
#  {'_id': ObjectId('617e02e00a74a2142647a5f5'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'MANUFACTURE / DELIVER - CRACK',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a5f6'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'MANUFACTURE / DELIVER - HALLUCINOGEN',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a5f7'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'MANUFACTURE / DELIVER - SYNTHETIC DRUGS',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5f8'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'POSSESS - AMPHETAMINES',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5f9'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'POSSESS - BARBITURATES',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a5fa'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'POSSESS - CANNABIS 30 GRAMS OR LESS',
#   'reported_crime': 4},
#  {'_id': ObjectId('617e02e00a74a2142647a5fb'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'POSSESS - CANNABIS MORE THAN 30 GRAMS',
#   'reported_crime': 17},
#  {'_id': ObjectId('617e02e00a74a2142647a5fc'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'POSSESS - COCAINE',
#   'reported_crime': 12},
#  {'_id': ObjectId('617e02e00a74a2142647a5fd'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'POSSESS - CRACK',
#   'reported_crime': 9},
#  {'_id': ObjectId('617e02e00a74a2142647a5fe'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'POSSESS - HEROIN (TAN / BROWN TAR)',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a5ff'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'POSSESS - HEROIN (WHITE)',
#   'reported_crime': 27},
#  {'_id': ObjectId('617e02e00a74a2142647a600'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'POSSESS - METHAMPHETAMINE',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a601'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'POSSESS - PCP',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a602'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'POSSESS - SYNTHETIC DRUGS',
#   'reported_crime': 11},
#  {'_id': ObjectId('617e02e00a74a2142647a603'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'POSSESSION OF DRUG EQUIPMENT',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a604'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'description': 'SOLICIT NARCOTICS ON PUBLIC WAY',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a605'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OBSCENITY',
#   'description': 'OBSCENE MATTER',
#   'reported_crime': 4},
#  {'_id': ObjectId('617e02e00a74a2142647a606'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'description': 'AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER',
#   'reported_crime': 15},
#  {'_id': ObjectId('617e02e00a74a2142647a607'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'description': 'AGGRAVATED SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER',
#   'reported_crime': 8},
#  {'_id': ObjectId('617e02e00a74a2142647a608'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'description': 'CHILD ABANDONMENT',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a609'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'description': 'CHILD ABDUCTION',
#   'reported_crime': 5},
#  {'_id': ObjectId('617e02e00a74a2142647a60a'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'description': 'CHILD ABUSE',
#   'reported_crime': 39},
#  {'_id': ObjectId('617e02e00a74a2142647a60b'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'description': 'CHILD PORNOGRAPHY',
#   'reported_crime': 5},
#  {'_id': ObjectId('617e02e00a74a2142647a60c'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'description': 'CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER',
#   'reported_crime': 4},
#  {'_id': ObjectId('617e02e00a74a2142647a60d'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'description': 'ENDANGERING LIFE / HEALTH OF CHILD',
#   'reported_crime': 13},
#  {'_id': ObjectId('617e02e00a74a2142647a60e'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'description': 'OTHER OFFENSE',
#   'reported_crime': 37},
#  {'_id': ObjectId('617e02e00a74a2142647a60f'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'ANIMAL ABUSE / NEGLECT',
#   'reported_crime': 4},
#  {'_id': ObjectId('617e02e00a74a2142647a610'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'BOARD PLANE WITH WEAPON',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a611'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'FALSE / STOLEN / ALTERED TRP',
#   'reported_crime': 18},
#  {'_id': ObjectId('617e02e00a74a2142647a612'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'GUN OFFENDER - ANNUAL REGISTRATION',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a613'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'GUN OFFENDER - DUTY TO REPORT CHANGE OF INFORMATION',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a614'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'HARASSMENT BY ELECTRONIC MEANS',
#   'reported_crime': 119},
#  {'_id': ObjectId('617e02e00a74a2142647a615'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'HARASSMENT BY TELEPHONE',
#   'reported_crime': 119},
#  {'_id': ObjectId('617e02e00a74a2142647a616'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'LICENSE VIOLATION',
#   'reported_crime': 8},
#  {'_id': ObjectId('617e02e00a74a2142647a617'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'OBSCENE TELEPHONE CALLS',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a618'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'OTHER CRIME AGAINST PERSON',
#   'reported_crime': 22},
#  {'_id': ObjectId('617e02e00a74a2142647a619'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'OTHER CRIME INVOLVING PROPERTY',
#   'reported_crime': 17},
#  {'_id': ObjectId('617e02e00a74a2142647a61a'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'OTHER VEHICLE OFFENSE',
#   'reported_crime': 70},
#  {'_id': ObjectId('617e02e00a74a2142647a61b'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'OTHER WEAPONS VIOLATION',
#   'reported_crime': 4},
#  {'_id': ObjectId('617e02e00a74a2142647a61c'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'POSSESSION OF BURGLARY TOOLS',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a61d'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'SEX OFFENDER - FAIL TO REGISTER',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a61e'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'TAMPER WITH MOTOR VEHICLE',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a61f'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'TELEPHONE THREAT',
#   'reported_crime': 220},
#  {'_id': ObjectId('617e02e00a74a2142647a620'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'VEHICLE TITLE / REGISTRATION OFFENSE',
#   'reported_crime': 8},
#  {'_id': ObjectId('617e02e00a74a2142647a621'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'VIOLATE ORDER OF PROTECTION',
#   'reported_crime': 108},
#  {'_id': ObjectId('617e02e00a74a2142647a622'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'VIOLATION GPS MONITORING DEVICE',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a623'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'VIOLATION OF BAIL BOND - DOMESTIC VIOLENCE',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a624'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'description': 'VIOLATION OF CIVIL NO CONTACT ORDER',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a625'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'PROSTITUTION',
#   'description': 'PIMPING',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a626'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'PROSTITUTION',
#   'description': 'SOLICITING FOR BUSINESS',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a627'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'description': 'ARSON THREAT',
#   'reported_crime': 8},
#  {'_id': ObjectId('617e02e00a74a2142647a628'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'description': 'BOMB THREAT',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a629'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'description': 'LOOTING',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a62a'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'description': 'MOB ACTION',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a62b'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'description': 'OTHER VIOLATION',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a62c'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'description': 'PEEPING TOM',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a62d'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'description': 'RECKLESS CONDUCT',
#   'reported_crime': 24},
#  {'_id': ObjectId('617e02e00a74a2142647a62e'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ROBBERY',
#   'description': 'AGGRAVATED',
#   'reported_crime': 26},
#  {'_id': ObjectId('617e02e00a74a2142647a62f'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ROBBERY',
#   'description': 'AGGRAVATED VEHICULAR HIJACKING',
#   'reported_crime': 44},
#  {'_id': ObjectId('617e02e00a74a2142647a630'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ROBBERY',
#   'description': 'ARMED - HANDGUN',
#   'reported_crime': 166},
#  {'_id': ObjectId('617e02e00a74a2142647a631'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ROBBERY',
#   'description': 'ARMED - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 22},
#  {'_id': ObjectId('617e02e00a74a2142647a632'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ROBBERY',
#   'description': 'ARMED - OTHER DANGEROUS WEAPON',
#   'reported_crime': 18},
#  {'_id': ObjectId('617e02e00a74a2142647a633'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ROBBERY',
#   'description': 'ATTEMPT AGGRAVATED',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a634'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ROBBERY',
#   'description': 'ATTEMPT ARMED - HANDGUN',
#   'reported_crime': 22},
#  {'_id': ObjectId('617e02e00a74a2142647a635'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ROBBERY',
#   'description': 'ATTEMPT ARMED - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 4},
#  {'_id': ObjectId('617e02e00a74a2142647a636'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ROBBERY',
#   'description': 'ATTEMPT ARMED - OTHER DANGEROUS WEAPON',
#   'reported_crime': 7},
#  {'_id': ObjectId('617e02e00a74a2142647a637'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ROBBERY',
#   'description': 'ATTEMPT STRONG ARM - NO WEAPON',
#   'reported_crime': 13},
#  {'_id': ObjectId('617e02e00a74a2142647a638'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ROBBERY',
#   'description': 'STRONG ARM - NO WEAPON',
#   'reported_crime': 111},
#  {'_id': ObjectId('617e02e00a74a2142647a639'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'ROBBERY',
#   'description': 'VEHICULAR HIJACKING',
#   'reported_crime': 20},
#  {'_id': ObjectId('617e02e00a74a2142647a63a'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'AGGRAVATED CRIMINAL SEXUAL ABUSE',
#   'reported_crime': 5},
#  {'_id': ObjectId('617e02e00a74a2142647a63b'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'CRIMINAL SEXUAL ABUSE',
#   'reported_crime': 10},
#  {'_id': ObjectId('617e02e00a74a2142647a63c'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'NON-CONSENSUAL DISSEMINATION OF PRIVATE SEXUAL IMAGES',
#   'reported_crime': 19},
#  {'_id': ObjectId('617e02e00a74a2142647a63d'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'OTHER',
#   'reported_crime': 11},
#  {'_id': ObjectId('617e02e00a74a2142647a63e'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'PUBLIC INDECENCY',
#   'reported_crime': 5},
#  {'_id': ObjectId('617e02e00a74a2142647a63f'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'SEXUAL EXPLOITATION OF A CHILD',
#   'reported_crime': 8},
#  {'_id': ObjectId('617e02e00a74a2142647a640'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'STALKING',
#   'description': 'CYBERSTALKING',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a641'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'STALKING',
#   'description': 'SIMPLE',
#   'reported_crime': 5},
#  {'_id': ObjectId('617e02e00a74a2142647a642'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'STALKING',
#   'description': 'VIOLATION OF STALKING NO CONTACT ORDER',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a643'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'THEFT',
#   'description': '$500 AND UNDER',
#   'reported_crime': 1140},
#  {'_id': ObjectId('617e02e00a74a2142647a644'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'THEFT',
#   'description': 'ATTEMPT THEFT',
#   'reported_crime': 18},
#  {'_id': ObjectId('617e02e00a74a2142647a645'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'THEFT',
#   'description': 'DELIVERY CONTAINER THEFT',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a646'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'THEFT',
#   'description': 'FROM BUILDING',
#   'reported_crime': 413},
#  {'_id': ObjectId('617e02e00a74a2142647a647'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'THEFT',
#   'description': 'FROM COIN-OPERATED MACHINE OR DEVICE',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a648'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'THEFT',
#   'description': 'OVER $500',
#   'reported_crime': 553},
#  {'_id': ObjectId('617e02e00a74a2142647a649'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'THEFT',
#   'description': 'POCKET-PICKING',
#   'reported_crime': 28},
#  {'_id': ObjectId('617e02e00a74a2142647a64a'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'THEFT',
#   'description': 'PURSE-SNATCHING',
#   'reported_crime': 11},
#  {'_id': ObjectId('617e02e00a74a2142647a64b'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'THEFT',
#   'description': 'RETAIL THEFT',
#   'reported_crime': 331},
#  {'_id': ObjectId('617e02e00a74a2142647a64c'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'DEFACE IDENTIFICATION MARKS OF FIREARM',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a64d'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'POSSESS FIREARM / AMMUNITION - NO FOID CARD',
#   'reported_crime': 8},
#  {'_id': ObjectId('617e02e00a74a2142647a64e'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'RECKLESS FIREARM DISCHARGE',
#   'reported_crime': 130},
#  {'_id': ObjectId('617e02e00a74a2142647a64f'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL POSSESSION - AMMUNITION',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a650'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL POSSESSION - HANDGUN',
#   'reported_crime': 244},
#  {'_id': ObjectId('617e02e00a74a2142647a651'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL POSSESSION - OTHER FIREARM',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a652'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL USE - HANDGUN',
#   'reported_crime': 57},
#  {'_id': ObjectId('617e02e00a74a2142647a653'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL USE - OTHER DANGEROUS WEAPON',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a654'),
#   'year': '2020',
#   'crime_month_name': 'April',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL USE - OTHER FIREARM',
#   'reported_crime': 25},
#  {'_id': ObjectId('617e02e00a74a2142647a655'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ARSON',
#   'description': 'AGGRAVATED',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a656'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ARSON',
#   'description': 'ATTEMPT ARSON',
#   'reported_crime': 4},
#  {'_id': ObjectId('617e02e00a74a2142647a657'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ARSON',
#   'description': 'BY FIRE',
#   'reported_crime': 51},
#  {'_id': ObjectId('617e02e00a74a2142647a658'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED - HANDGUN',
#   'reported_crime': 378},
#  {'_id': ObjectId('617e02e00a74a2142647a659'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 121},
#  {'_id': ObjectId('617e02e00a74a2142647a65a'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED - OTHER DANGEROUS WEAPON',
#   'reported_crime': 85},
#  {'_id': ObjectId('617e02e00a74a2142647a65b'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED - OTHER FIREARM',
#   'reported_crime': 9},
#  {'_id': ObjectId('617e02e00a74a2142647a65c'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED POLICE OFFICER - HANDGUN',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a65d'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED POLICE OFFICER - HANDS, FISTS, FEET, NO INJURY',
#   'reported_crime': 17},
#  {'_id': ObjectId('617e02e00a74a2142647a65e'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a65f'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a660'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED PROTECTED EMPLOYEE - HANDGUN',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a661'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 4},
#  {'_id': ObjectId('617e02e00a74a2142647a662'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a663'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ASSAULT',
#   'description': 'PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY',
#   'reported_crime': 17},
#  {'_id': ObjectId('617e02e00a74a2142647a664'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'ASSAULT',
#   'description': 'SIMPLE',
#   'reported_crime': 1180},
#  {'_id': ObjectId('617e02e00a74a2142647a665'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
#   'description': 'AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY',
#   'reported_crime': 59},
#  {'_id': ObjectId('617e02e00a74a2142647a666'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
#   'description': 'AGG. PROTECTED EMPLOYEE - HANDS, FISTS, FEET, SERIOUS INJURY',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a667'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED - HANDGUN',
#   'reported_crime': 303},
#  {'_id': ObjectId('617e02e00a74a2142647a668'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED - HANDS, FISTS, FEET, NO / MINOR INJURY',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a669'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED - HANDS, FISTS, FEET, SERIOUS INJURY',
#   'reported_crime': 12},
#  {'_id': ObjectId('617e02e00a74a2142647a66a'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 91},
#  {'_id': ObjectId('617e02e00a74a2142647a66b'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED - OTHER DANGEROUS WEAPON',
#   'reported_crime': 197},
#  {'_id': ObjectId('617e02e00a74a2142647a66c'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED - OTHER FIREARM',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a66d'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED DOMESTIC BATTERY - HANDGUN',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a66e'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED DOMESTIC BATTERY - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 63},
#  {'_id': ObjectId('617e02e00a74a2142647a66f'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS WEAPON',
#   'reported_crime': 131},
#  {'_id': ObjectId('617e02e00a74a2142647a670'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED OF A CHILD',
#   'reported_crime': 9},
#  {'_id': ObjectId('617e02e00a74a2142647a671'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
#   'description': 'AGGRAVATED OF A SENIOR CITIZEN',
#   'reported_crime': 27},
#  {'_id': ObjectId('617e02e00a74a2142647a672'),
#   'year': '2020',
#   'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
# ...
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a921'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'description': 'ATTEMPT ARMED: HANDGUN',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a922'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'description': 'ATTEMPT STRONG ARM - NO WEAPON',
#   'reported_crime': 9},
#  {'_id': ObjectId('617e02e00a74a2142647a923'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'description': 'ATTEMPT STRONG ARM: NO WEAPON',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a924'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'description': 'ATTEMPT: AGGRAVATED',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a925'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'description': 'ATTEMPT: ARMED-HANDGUN',
#   'reported_crime': 9},
#  {'_id': ObjectId('617e02e00a74a2142647a926'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'description': 'ATTEMPT: ARMED-KNIFE/CUT INSTR',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a927'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'description': 'ATTEMPT: ARMED-OTHER DANG WEAP',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a928'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'description': 'ATTEMPT: ARMED-OTHER FIREARM',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a929'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'description': 'ATTEMPT: STRONGARM-NO WEAPON',
#   'reported_crime': 17},
#  {'_id': ObjectId('617e02e00a74a2142647a92a'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'description': 'STRONG ARM - NO WEAPON',
#   'reported_crime': 86},
#  {'_id': ObjectId('617e02e00a74a2142647a92b'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'description': 'STRONGARM - NO WEAPON',
#   'reported_crime': 100},
#  {'_id': ObjectId('617e02e00a74a2142647a92c'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'description': 'STRONGARM: NO WEAPON',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a92d'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'description': 'VEHICULAR HIJACKING',
#   'reported_crime': 23},
#  {'_id': ObjectId('617e02e00a74a2142647a92e'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'AGG CRIMINAL SEXUAL ABUSE',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a92f'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'AGGRAVATED CRIMINAL SEXUAL ABUSE',
#   'reported_crime': 11},
#  {'_id': ObjectId('617e02e00a74a2142647a930'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'ATTEMPT CRIMINAL SEXUAL ABUSE',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a931'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'CRIMINAL SEXUAL ABUSE',
#   'reported_crime': 32},
#  {'_id': ObjectId('617e02e00a74a2142647a932'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'CRIMINAL TRANSMISSION OF HIV',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a933'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'INDECENT SOLICITATION OF A CHILD',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a934'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'INDECENT SOLICITATION/ADULT',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a935'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'NON-CONSENSUAL DISSEMINATION OF PRIVATE SEXUAL IMAGES',
#   'reported_crime': 11},
#  {'_id': ObjectId('617e02e00a74a2142647a936'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'NON-CONSENSUAL DISSEMINATION PRIVATE SEXUAL IMAGES',
#   'reported_crime': 4},
#  {'_id': ObjectId('617e02e00a74a2142647a937'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'OTHER',
#   'reported_crime': 7},
#  {'_id': ObjectId('617e02e00a74a2142647a938'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'PUBLIC INDECENCY',
#   'reported_crime': 17},
#  {'_id': ObjectId('617e02e00a74a2142647a939'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'description': 'SEXUAL EXPLOITATION OF A CHILD',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a93a'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'STALKING',
#   'description': 'CYBERSTALKING',
#   'reported_crime': 5},
#  {'_id': ObjectId('617e02e00a74a2142647a93b'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'STALKING',
#   'description': 'SIMPLE',
#   'reported_crime': 11},
#  {'_id': ObjectId('617e02e00a74a2142647a93c'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'STALKING',
#   'description': 'VIOLATION OF STALKING NO CONTACT ORDER',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a93d'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'THEFT',
#   'description': '$500 AND UNDER',
#   'reported_crime': 1539},
#  {'_id': ObjectId('617e02e00a74a2142647a93e'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'THEFT',
#   'description': 'ATTEMPT THEFT',
#   'reported_crime': 20},
#  {'_id': ObjectId('617e02e00a74a2142647a93f'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'THEFT',
#   'description': 'DELIVERY CONTAINER THEFT',
#   'reported_crime': 8},
#  {'_id': ObjectId('617e02e00a74a2142647a940'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'THEFT',
#   'description': 'FROM BUILDING',
#   'reported_crime': 697},
#  {'_id': ObjectId('617e02e00a74a2142647a941'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'THEFT',
#   'description': 'OVER $500',
#   'reported_crime': 958},
#  {'_id': ObjectId('617e02e00a74a2142647a942'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'THEFT',
#   'description': 'POCKET-PICKING',
#   'reported_crime': 145},
#  {'_id': ObjectId('617e02e00a74a2142647a943'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'THEFT',
#   'description': 'PURSE-SNATCHING',
#   'reported_crime': 22},
#  {'_id': ObjectId('617e02e00a74a2142647a944'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'THEFT',
#   'description': 'RETAIL THEFT',
#   'reported_crime': 787},
#  {'_id': ObjectId('617e02e00a74a2142647a945'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'DEFACE IDENT MARKS OF FIREARM',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a946'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'POSS FIREARM/AMMO:NO FOID CARD',
#   'reported_crime': 12},
#  {'_id': ObjectId('617e02e00a74a2142647a947'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'POSSESS FIREARM / AMMUNITION - NO FOID CARD',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a948'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'RECKLESS FIREARM DISCHARGE',
#   'reported_crime': 68},
#  {'_id': ObjectId('617e02e00a74a2142647a949'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL POSS AMMUNITION',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a94a'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL POSS OF HANDGUN',
#   'reported_crime': 311},
#  {'_id': ObjectId('617e02e00a74a2142647a94b'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL POSS OTHER FIREARM',
#   'reported_crime': 5},
#  {'_id': ObjectId('617e02e00a74a2142647a94c'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL POSSESSION - HANDGUN',
#   'reported_crime': 9},
#  {'_id': ObjectId('617e02e00a74a2142647a94d'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL POSSESSION - OTHER FIREARM',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a94e'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL USE - HANDGUN',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a94f'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL USE HANDGUN',
#   'reported_crime': 28},
#  {'_id': ObjectId('617e02e00a74a2142647a950'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL USE OTHER DANG WEAPON',
#   'reported_crime': 7},
#  {'_id': ObjectId('617e02e00a74a2142647a951'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL USE OTHER FIREARM',
#   'reported_crime': 5},
#  {'_id': ObjectId('617e02e00a74a2142647a952'),
#   'year': '2020',
#   'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'description': 'UNLAWFUL USE/SALE AIR RIFLE',
#   'reported_crime': 5},
#  {'_id': ObjectId('617e02e00a74a2142647a953'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ARSON',
#   'description': 'AGGRAVATED',
#   'reported_crime': 5},
#  {'_id': ObjectId('617e02e00a74a2142647a954'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ARSON',
#   'description': 'ATTEMPT ARSON',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a955'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ARSON',
#   'description': 'BY FIRE',
#   'reported_crime': 15},
#  {'_id': ObjectId('617e02e00a74a2142647a956'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGG PO HANDS NO/MIN INJURY',
#   'reported_crime': 17},
#  {'_id': ObjectId('617e02e00a74a2142647a957'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGG PRO.EMP: HANDGUN',
#   'reported_crime': 4},
#  {'_id': ObjectId('617e02e00a74a2142647a958'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGG PRO.EMP: OTHER DANG WEAPON',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a959'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGG PRO.EMP:KNIFE/CUTTING INST',
#   'reported_crime': 4},
#  {'_id': ObjectId('617e02e00a74a2142647a95a'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED - HANDGUN',
#   'reported_crime': 30},
#  {'_id': ObjectId('617e02e00a74a2142647a95b'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED - OTHER DANGEROUS WEAPON',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a95c'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED PO: HANDGUN',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a95d'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED PO: OTHER DANG WEAP',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a95e'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED PO:KNIFE/CUT INSTR',
#   'reported_crime': 5},
#  {'_id': ObjectId('617e02e00a74a2142647a95f'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED POLICE OFFICER - HANDGUN',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a960'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a961'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a962'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED: HANDGUN',
#   'reported_crime': 170},
#  {'_id': ObjectId('617e02e00a74a2142647a963'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED: OTHER DANG WEAPON',
#   'reported_crime': 72},
#  {'_id': ObjectId('617e02e00a74a2142647a964'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED: OTHER FIREARM',
#   'reported_crime': 6},
#  {'_id': ObjectId('617e02e00a74a2142647a965'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'AGGRAVATED:KNIFE/CUTTING INSTR',
#   'reported_crime': 132},
#  {'_id': ObjectId('617e02e00a74a2142647a966'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'PRO EMP HANDS NO/MIN INJURY',
#   'reported_crime': 58},
#  {'_id': ObjectId('617e02e00a74a2142647a967'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a968'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'description': 'SIMPLE',
#   'reported_crime': 1005},
#  {'_id': ObjectId('617e02e00a74a2142647a969'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'BATTERY',
#   'description': 'AGG PO HANDS ETC SERIOUS INJ',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a96a'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'BATTERY',
#   'description': 'AGG PO HANDS NO/MIN INJURY',
#   'reported_crime': 47},
#  {'_id': ObjectId('617e02e00a74a2142647a96b'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'BATTERY',
#   'description': 'AGG PRO EMP HANDS SERIOUS INJ',
#   'reported_crime': 2},
#  {'_id': ObjectId('617e02e00a74a2142647a96c'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'BATTERY',
#   'description': 'AGG PRO.EMP: OTHER DANG WEAPON',
#   'reported_crime': 7},
#  {'_id': ObjectId('617e02e00a74a2142647a96d'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'BATTERY',
#   'description': 'AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY',
#   'reported_crime': 3},
#  {'_id': ObjectId('617e02e00a74a2142647a96e'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'BATTERY',
#   'description': 'AGG. PROTECTED EMPLOYEE - HANDS, FISTS, FEET, SERIOUS INJURY',
#   'reported_crime': 1},
#  {'_id': ObjectId('617e02e00a74a2142647a96f'),
#   'year': '2020',
#   'crime_month_name': 'January',
#   'primary_type': 'BATTERY',
#   'description': 'AGG: HANDS/FIST/FEET NO/MINOR INJURY',
#   'reported_crime': 16},
#  ...]
